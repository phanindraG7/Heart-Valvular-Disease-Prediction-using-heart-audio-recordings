# %%
import os
import time
import numpy as np
import pandas as pd
import scipy.io as sio
from scipy.fftpack import fft
from IPython.display import display

import pywt
import scipy.stats

import datetime as dt
from collections import defaultdict, Counter

from sklearn.ensemble import GradientBoostingClassifier

# %%
# Define statistical feature calculation function
def calculate_statistics(list_values):
    n5 = np.nanpercentile(list_values, 5)
    n25 = np.nanpercentile(list_values, 25)
    n75 = np.nanpercentile(list_values, 75)
    n95 = np.nanpercentile(list_values, 95)
    median = np.nanpercentile(list_values, 50)
    mean = np.nanmean(list_values)
    std = np.nanstd(list_values)
    var = np.nanvar(list_values)
    rms = np.nanmean(np.sqrt(list_values**2))
    return [n5, n25, n75, n95, median, mean, std, var, rms]

def calculate_entropy(list_values):
    counter_values = Counter(list_values).most_common()
    probabilities = [elem[1]/len(list_values) for elem in counter_values]
    entropy=scipy.stats.entropy(probabilities)
    return entropy

def calculate_crossings(list_values):
    zero_crossing_indices = np.nonzero(np.diff(np.array(list_values) > 0))[0]
    no_zero_crossings = len(zero_crossing_indices)
    mean_crossing_indices = np.nonzero(np.diff(np.array(list_values) > np.nanmean(list_values)))[0]
    no_mean_crossings = len(mean_crossing_indices)
    return [no_zero_crossings, no_mean_crossings]

def get_features(list_values):
    #entropy = calculate_entropy(list_values)
    crossings = calculate_crossings(list_values)
    statistics = calculate_statistics(list_values)
    entropy = calculate_entropy(list_values)
    return  [entropy]+crossings + statistics

def get_train_test(df, y_col, x_cols, ratio):
    """ 
    This method transforms a dataframe into a train and test set, for this you need to specify:
    1. the ratio train : test (usually 0.7)
    2. the column with the Y_values
    """
    mask = np.random.rand(len(df)) < ratio
    df_train = df[mask]
    df_test = df[~mask]
       
    Y_train = df_train[y_col].values
    Y_test = df_test[y_col].values
    X_train = df_train[x_cols].values
    X_test = df_test[x_cols].values
    return df_train, df_test, X_train, Y_train, X_test, Y_test

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm
import pywt
from scipy.io import wavfile

# wavelet = 'morl'  # wavelet type: morlet
# sr = 8000  # sampling frequency: 8KHz
# widths = np.arange(1, 256)  # scales for morlet wavelet
# dt = 1 / sr  # timestep difference

# Define function for feature extraction using DWT
def features_extractor(file_path):
    scales = np.arange(1, 31) 
    sample_rate, audio_data = wavfile.read(file_path)
    coeffs, _ = pywt.cwt(audio_data, scales, 'morl') 
    features = []
    for coeff in coeffs:
        # Calculate statistical features for each coefficient
        features += get_features(coeff)  # Assuming you have a function get_features() that returns features
    return features

# Define path and mappings
audio_dataset_path = r"D:\SDP\Dataset"
metadata = pd.read_csv('HVD_Data.csv')

label_to_folder = {
    "AS": "AS_New",
    "MR": "MR_New",
    "MS": "MS_New",
    "MVP": "MVP_New",
    "N": "N_New"
}

# Iterate through metadata and extract features
extracted_features = []
list_labels = []  # List to store labels
for index_num, row in tqdm(metadata.iterrows()):
    file_label = row["Label"]  # Change "Label" to the correct column name
    folder_name = label_to_folder.get(file_label)
    if folder_name:
        file_name = os.path.join(audio_dataset_path, folder_name, row["Name"])
        features = features_extractor(file_name) 
        extracted_features.append(features)
        list_labels.append(file_label)

# Create DataFrame from extracted features and labels
df = pd.DataFrame(extracted_features)
df['label'] = list_labels

# Split data into train and test sets (You can use train_test_split from sklearn)
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['label'])  # Adjust test_size as needed

# Separate features and labels for train and test sets
X_train, Y_train = df_train.drop('label', axis=1), df_train['label']
X_test, Y_test = df_test.drop('label', axis=1), df_test['label']
# Out:
# 1000it [09:29,  1.76it/s]

# %%
X_train.shape
# Out:
# (800, 360)

# %% [markdown]
# ### Gradient Booster

# %%
cls = GradientBoostingClassifier(n_estimators=10000)
cls.fit(X_train, Y_train)
train_score = cls.score(X_train, Y_train)
test_score = cls.score(X_test, Y_test)
print("The Train Score is {}".format(train_score))
print("The Test Score is {}".format(test_score))
# Out:
# The Train Score is 1.0
# The Test Score is 0.985

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(conf_matrix, title):
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_to_folder))
    plt.xticks(tick_marks, label_to_folder.keys(), rotation=45)
    plt.yticks(tick_marks, label_to_folder.keys())
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    for i in range(len(conf_matrix)):
        for j in range(len(conf_matrix)):
            plt.text(j, i, format(conf_matrix[i, j]), horizontalalignment="center", color="white" if conf_matrix[i, j] > np.max(conf_matrix)/2 else "black")
    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Predictions
y_train_pred_gb = cls.predict(X_train)
y_test_pred_gb = cls.predict(X_test)

# Calculate confusion matrix for training data
conf_matrix_train_gb = confusion_matrix(Y_train, y_train_pred_gb)

# Calculate confusion matrix for testing data
conf_matrix_test_gb = confusion_matrix(Y_test, y_test_pred_gb)

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train_gb, title="Confusion Matrix - Training Data (Gradient Boosting)")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test_gb, title="Confusion Matrix - Testing Data (Gradient Boosting)")

# %% [markdown]
# ### ANN

# %%
# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow.keras import layers, models

# Create a simple ANN model
model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(360,)),  # Specify input shape
    layers.Dense(64, activation='relu'),
    layers.Dense(5, activation='softmax')  # Assuming 5 classes
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])


from sklearn.preprocessing import LabelEncoder

# Encode labels
label_encoder = LabelEncoder()
Y_train_encoded = label_encoder.fit_transform(Y_train)
Y_test_encoded = label_encoder.transform(Y_test)

# Train the model
history = model.fit(X_train, Y_train_encoded,batch_size=32, epochs=100, validation_data=(X_test, Y_test_encoded))

# Evaluate the model
train_score_ann = model.evaluate(X_train, Y_train_encoded, verbose=0)
test_score_ann = model.evaluate(X_test, Y_test_encoded, verbose=0)

# Print scores
print("ANN Train Score:", train_score_ann[1])
print("ANN Test Score:", test_score_ann[1])
# Out:
# Epoch 1/100
# C:\Users\G phanindra\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:88: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 18ms/step - accuracy: 0.2194 - loss: 2864354.5000 - val_accuracy: 0.2450 - val_loss: 248648.3438
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3221 - loss: 346748.1250 - val_accuracy: 0.4400 - val_loss: 257800.7500
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5423 - loss: 281546.3125 - val_accuracy: 0.5250 - val_loss: 244855.0156
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5152 - loss: 171757.5469 - val_accuracy: 0.4600 - val_loss: 240950.9688
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5450 - loss: 187777.6875 - val_accuracy: 0.5900 - val_loss: 115754.6328
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5773 - loss: 147920.9688 - val_accuracy: 0.7350 - val_loss: 122083.4375
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6905 - loss: 137443.1875 - val_accuracy: 0.7400 - val_loss: 61144.8320
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6902 - loss: 83893.9453 - val_accuracy: 0.7700 - val_loss: 32934.1484
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5843 - loss: 135686.2344 - val_accuracy: 0.6200 - val_loss: 53426.3984
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6334 - loss: 107240.7734 - val_accuracy: 0.6050 - val_loss: 122133.7422
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5728 - loss: 146171.7969 - val_accuracy: 0.6800 - val_loss: 114325.4766
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6649 - loss: 120526.1641 - val_accuracy: 0.5800 - val_loss: 122408.9297
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6376 - loss: 137175.8281 - val_accuracy: 0.6750 - val_loss: 56625.6836
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6964 - loss: 91569.0078 - val_accuracy: 0.6700 - val_loss: 182757.0156
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6287 - loss: 130757.6562 - val_accuracy: 0.7400 - val_loss: 125388.3359
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5433 - loss: 184377.2500 - val_accuracy: 0.4150 - val_loss: 164678.6719
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5214 - loss: 262050.5469 - val_accuracy: 0.5850 - val_loss: 168246.0781
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6023 - loss: 146412.7969 - val_accuracy: 0.3900 - val_loss: 149732.5000
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6266 - loss: 89635.8984 - val_accuracy: 0.6800 - val_loss: 51867.9648
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6155 - loss: 121169.1562 - val_accuracy: 0.7150 - val_loss: 47683.0586
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6539 - loss: 91222.7500 - val_accuracy: 0.6450 - val_loss: 139132.0625
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6222 - loss: 139766.3750 - val_accuracy: 0.7300 - val_loss: 74077.8359
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6783 - loss: 114144.6719 - val_accuracy: 0.6750 - val_loss: 158235.4531
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6906 - loss: 76808.5156 - val_accuracy: 0.7150 - val_loss: 96035.2422
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6423 - loss: 101804.1250 - val_accuracy: 0.7550 - val_loss: 61509.3750
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7199 - loss: 82682.2734 - val_accuracy: 0.6900 - val_loss: 50655.6250
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7197 - loss: 64754.7383 - val_accuracy: 0.6750 - val_loss: 66090.1016
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7338 - loss: 63064.9531 - val_accuracy: 0.7650 - val_loss: 53531.0000
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7211 - loss: 80573.1406 - val_accuracy: 0.6200 - val_loss: 51774.4453
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6935 - loss: 66195.0000 - val_accuracy: 0.6000 - val_loss: 124645.2031
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6707 - loss: 66458.0859 - val_accuracy: 0.7500 - val_loss: 112603.9219
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6299 - loss: 179336.7500 - val_accuracy: 0.6200 - val_loss: 52614.9180
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.5546 - loss: 122118.8125 - val_accuracy: 0.7050 - val_loss: 67984.8281
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6117 - loss: 125272.5625 - val_accuracy: 0.6050 - val_loss: 254131.5938
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5774 - loss: 167137.4844 - val_accuracy: 0.7200 - val_loss: 36989.8008
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6624 - loss: 96669.0859 - val_accuracy: 0.7400 - val_loss: 56694.0000
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7164 - loss: 65952.1484 - val_accuracy: 0.7650 - val_loss: 31502.7402
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7834 - loss: 27760.4609 - val_accuracy: 0.6550 - val_loss: 63280.2734
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6777 - loss: 63222.7695 - val_accuracy: 0.5400 - val_loss: 109732.3281
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6974 - loss: 75428.3516 - val_accuracy: 0.5900 - val_loss: 202893.6406
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6566 - loss: 156191.2969 - val_accuracy: 0.6400 - val_loss: 83066.6484
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6137 - loss: 179423.5000 - val_accuracy: 0.6550 - val_loss: 181864.4531
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5844 - loss: 266215.5625 - val_accuracy: 0.7650 - val_loss: 42798.1523
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6936 - loss: 104480.8984 - val_accuracy: 0.7000 - val_loss: 174372.1250
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6854 - loss: 113457.5234 - val_accuracy: 0.7750 - val_loss: 32994.4141
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7157 - loss: 69305.9688 - val_accuracy: 0.7450 - val_loss: 45441.1133
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6764 - loss: 54404.7539 - val_accuracy: 0.7050 - val_loss: 103284.7422
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6800 - loss: 103749.2500 - val_accuracy: 0.7100 - val_loss: 43284.9102
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6853 - loss: 81561.9297 - val_accuracy: 0.6850 - val_loss: 78699.9141
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6953 - loss: 57774.9336 - val_accuracy: 0.7850 - val_loss: 31469.2461
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8031 - loss: 31561.3613 - val_accuracy: 0.7800 - val_loss: 51342.2070
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7653 - loss: 58608.2930 - val_accuracy: 0.7650 - val_loss: 47713.6836
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7711 - loss: 41434.8750 - val_accuracy: 0.6900 - val_loss: 38184.8125
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7458 - loss: 51496.2617 - val_accuracy: 0.7600 - val_loss: 37160.4688
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7666 - loss: 44121.2422 - val_accuracy: 0.7650 - val_loss: 38221.2461
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7785 - loss: 26942.9648 - val_accuracy: 0.7750 - val_loss: 25948.0762
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7618 - loss: 42791.3320 - val_accuracy: 0.7850 - val_loss: 44614.7109
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6924 - loss: 95276.0781 - val_accuracy: 0.6800 - val_loss: 121617.0391
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7320 - loss: 75482.7500 - val_accuracy: 0.7650 - val_loss: 26877.0938
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7794 - loss: 20177.1621 - val_accuracy: 0.7650 - val_loss: 24027.4258
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7732 - loss: 18498.2012 - val_accuracy: 0.6950 - val_loss: 37342.8711
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7438 - loss: 39573.0391 - val_accuracy: 0.6250 - val_loss: 127238.0781
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7018 - loss: 65630.8125 - val_accuracy: 0.7650 - val_loss: 72127.0234
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7824 - loss: 61883.7969 - val_accuracy: 0.7850 - val_loss: 41411.6797
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7291 - loss: 47072.6211 - val_accuracy: 0.6850 - val_loss: 50104.1445
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7169 - loss: 36704.6914 - val_accuracy: 0.8050 - val_loss: 20446.5332
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7658 - loss: 32980.0938 - val_accuracy: 0.7850 - val_loss: 17406.8281
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8068 - loss: 37370.5703 - val_accuracy: 0.8250 - val_loss: 45292.8672
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7780 - loss: 45046.2734 - val_accuracy: 0.7900 - val_loss: 18424.6504
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8122 - loss: 26565.4375 - val_accuracy: 0.7800 - val_loss: 24255.5488
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8023 - loss: 22100.0664 - val_accuracy: 0.7800 - val_loss: 32038.3262
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7203 - loss: 52835.3438 - val_accuracy: 0.6700 - val_loss: 141712.0312
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6780 - loss: 93356.3281 - val_accuracy: 0.7650 - val_loss: 34667.3359
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7382 - loss: 35753.1953 - val_accuracy: 0.7450 - val_loss: 35863.4531
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7518 - loss: 58899.3633 - val_accuracy: 0.6650 - val_loss: 50336.3750
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7200 - loss: 35420.5273 - val_accuracy: 0.6700 - val_loss: 103432.8359
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7083 - loss: 57466.4727 - val_accuracy: 0.7600 - val_loss: 21215.5938
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7804 - loss: 27365.2500 - val_accuracy: 0.8250 - val_loss: 16998.4727
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8319 - loss: 28289.5977 - val_accuracy: 0.8100 - val_loss: 25908.2031
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7650 - loss: 26599.6973 - val_accuracy: 0.7800 - val_loss: 13978.8857
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7687 - loss: 25728.4492 - val_accuracy: 0.7200 - val_loss: 19542.9375
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8072 - loss: 13235.1465 - val_accuracy: 0.7950 - val_loss: 10157.9600
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7859 - loss: 22012.9434 - val_accuracy: 0.6550 - val_loss: 72045.0391
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6675 - loss: 65749.5859 - val_accuracy: 0.6300 - val_loss: 101293.9531
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7263 - loss: 50917.6758 - val_accuracy: 0.7850 - val_loss: 64349.9688
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7837 - loss: 61182.4922 - val_accuracy: 0.7400 - val_loss: 18876.2012
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6895 - loss: 58575.8359 - val_accuracy: 0.7550 - val_loss: 21721.7051
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7621 - loss: 31993.9785 - val_accuracy: 0.7500 - val_loss: 26623.0586
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8065 - loss: 21198.6758 - val_accuracy: 0.7300 - val_loss: 37055.6133
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8080 - loss: 23599.1289 - val_accuracy: 0.6800 - val_loss: 35493.4141
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7421 - loss: 35749.9883 - val_accuracy: 0.7600 - val_loss: 17772.6914
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7572 - loss: 33154.2617 - val_accuracy: 0.7400 - val_loss: 68348.7891
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7850 - loss: 63990.0039 - val_accuracy: 0.8350 - val_loss: 16117.0244
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8370 - loss: 15989.7012 - val_accuracy: 0.8050 - val_loss: 12998.0645
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7993 - loss: 18951.6992 - val_accuracy: 0.8600 - val_loss: 11374.5928
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7993 - loss: 27111.4141 - val_accuracy: 0.6500 - val_loss: 62795.4883
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7338 - loss: 27896.4180 - val_accuracy: 0.7250 - val_loss: 18109.5215
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7699 - loss: 17835.3672 - val_accuracy: 0.8300 - val_loss: 36679.8164
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8159 - loss: 23041.8555 - val_accuracy: 0.7000 - val_loss: 25960.4824
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7115 - loss: 38078.7227 - val_accuracy: 0.6450 - val_loss: 35684.3906
# ANN Train Score: 0.6474999785423279
# ANN Test Score: 0.6449999809265137

# %%
# Predictions
y_train_pred_ann_probs = model.predict(X_train)
y_train_pred_ann = np.argmax(y_train_pred_ann_probs, axis=1)

y_test_pred_ann_probs = model.predict(X_test)
y_test_pred_ann = np.argmax(y_test_pred_ann_probs, axis=1)

# Calculate confusion matrix for training data
conf_matrix_train_ann = confusion_matrix(Y_train_encoded, y_train_pred_ann)

# Calculate confusion matrix for testing data
conf_matrix_test_ann = confusion_matrix(Y_test_encoded, y_test_pred_ann)

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train_ann, title="Confusion Matrix - Training Data (ANN)")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test_ann, title="Confusion Matrix - Testing Data (ANN)")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Create KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (n_neighbors) as needed

# Train the model
knn_model.fit(X_train, Y_train_encoded)  # Use integer-encoded labels directly

# Predictions
y_train_pred_knn = knn_model.predict(X_train)
y_test_pred_knn = knn_model.predict(X_test)

# Calculate accuracy
train_accuracy_knn = accuracy_score(Y_train_encoded, y_train_pred_knn)
test_accuracy_knn = accuracy_score(Y_test_encoded, y_test_pred_knn)

print("Training Accuracy (KNN):", train_accuracy_knn)
print("Testing Accuracy (KNN):", test_accuracy_knn)
# Out:
# Training Accuracy (KNN): 0.91125
# Testing Accuracy (KNN): 0.86

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Calculate confusion matrix for training data
conf_matrix_train_knn = confusion_matrix(Y_train_encoded, y_train_pred_knn)

# Calculate confusion matrix for testing data
conf_matrix_test_knn = confusion_matrix(Y_test_encoded, y_test_pred_knn)

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train_knn, title="Confusion Matrix - Training Data (KNN)")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test_knn, title="Confusion Matrix - Testing Data (KNN)")

# %% [markdown]
# =

# %% [markdown]
# ### LSTM

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import accuracy_score

# Assuming you have already defined X_train, X_test, Y_train_encoded, and Y_test_encoded

# Reshape X_train and X_test
X_train_reshaped = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test_reshaped = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define LSTM model
lstm_model = Sequential([
    LSTM(64, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])),
    Dense(5, activation='softmax')
])

# Compile the model
lstm_model.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# Train the model
lstm_model.fit(X_train_reshaped, Y_train_encoded, epochs=100, validation_data=(X_test_reshaped, Y_test_encoded))

# Predictions
y_train_pred_lstm_probs = lstm_model.predict(X_train_reshaped)
y_train_pred_lstm = np.argmax(y_train_pred_lstm_probs, axis=1)

y_test_pred_lstm_probs = lstm_model.predict(X_test_reshaped)
y_test_pred_lstm = np.argmax(y_test_pred_lstm_probs, axis=1)

# Calculate accuracy
train_accuracy_lstm = accuracy_score(Y_train_encoded, y_train_pred_lstm)
test_accuracy_lstm = accuracy_score(Y_test_encoded, y_test_pred_lstm)

print("Training Accuracy (LSTM):", train_accuracy_lstm)
print("Testing Accuracy (LSTM):", test_accuracy_lstm)
# Out:
# Epoch 1/100
# C:\Users\G phanindra\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 231ms/step - accuracy: 0.2377 - loss: 1.6231 - val_accuracy: 0.3300 - val_loss: 1.5251
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.3521 - loss: 1.5149 - val_accuracy: 0.4000 - val_loss: 1.4564
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.3453 - loss: 1.4657 - val_accuracy: 0.4000 - val_loss: 1.3745
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.4163 - loss: 1.3763 - val_accuracy: 0.3900 - val_loss: 1.3257
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 185ms/step - accuracy: 0.4017 - loss: 1.3482 - val_accuracy: 0.3900 - val_loss: 1.2992
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.3995 - loss: 1.3218 - val_accuracy: 0.4700 - val_loss: 1.2799
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.4954 - loss: 1.3142 - val_accuracy: 0.4200 - val_loss: 1.2649
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.4929 - loss: 1.2721 - val_accuracy: 0.5000 - val_loss: 1.2463
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 184ms/step - accuracy: 0.5309 - loss: 1.2495 - val_accuracy: 0.5150 - val_loss: 1.2241
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.5175 - loss: 1.2455 - val_accuracy: 0.5300 - val_loss: 1.2152
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.5522 - loss: 1.2172 - val_accuracy: 0.5100 - val_loss: 1.1990
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.5327 - loss: 1.2207 - val_accuracy: 0.5250 - val_loss: 1.1928
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.5244 - loss: 1.2030 - val_accuracy: 0.4550 - val_loss: 1.1899
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.5201 - loss: 1.1960 - val_accuracy: 0.4400 - val_loss: 1.1870
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 0.5163 - loss: 1.2016 - val_accuracy: 0.5300 - val_loss: 1.1523
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5283 - loss: 1.1839 - val_accuracy: 0.4900 - val_loss: 1.1648
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5257 - loss: 1.1825 - val_accuracy: 0.5150 - val_loss: 1.1412
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.5370 - loss: 1.1516 - val_accuracy: 0.5300 - val_loss: 1.1193
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 171ms/step - accuracy: 0.5291 - loss: 1.1698 - val_accuracy: 0.5350 - val_loss: 1.1154
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.5054 - loss: 1.1610 - val_accuracy: 0.5650 - val_loss: 1.0966
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5604 - loss: 1.1104 - val_accuracy: 0.5400 - val_loss: 1.1047
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5646 - loss: 1.1247 - val_accuracy: 0.5550 - val_loss: 1.0737
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.5540 - loss: 1.1184 - val_accuracy: 0.5550 - val_loss: 1.0799
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 172ms/step - accuracy: 0.5611 - loss: 1.1011 - val_accuracy: 0.5850 - val_loss: 1.0532
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.5696 - loss: 1.0955 - val_accuracy: 0.5850 - val_loss: 1.0488
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5727 - loss: 1.0949 - val_accuracy: 0.5650 - val_loss: 1.0480
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5999 - loss: 1.0395 - val_accuracy: 0.5900 - val_loss: 1.0205
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.5830 - loss: 1.0631 - val_accuracy: 0.5700 - val_loss: 1.0366
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.5790 - loss: 1.0706 - val_accuracy: 0.5650 - val_loss: 1.0468
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.5751 - loss: 1.0566 - val_accuracy: 0.5900 - val_loss: 1.0077
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 178ms/step - accuracy: 0.5959 - loss: 1.0605 - val_accuracy: 0.6200 - val_loss: 0.9854
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5913 - loss: 1.0121 - val_accuracy: 0.5950 - val_loss: 0.9840
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 173ms/step - accuracy: 0.5799 - loss: 1.0344 - val_accuracy: 0.6050 - val_loss: 0.9751
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.5886 - loss: 0.9894 - val_accuracy: 0.6150 - val_loss: 0.9638
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.5968 - loss: 1.0098 - val_accuracy: 0.6150 - val_loss: 0.9426
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 176ms/step - accuracy: 0.5831 - loss: 1.0035 - val_accuracy: 0.6400 - val_loss: 0.9613
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 177ms/step - accuracy: 0.5892 - loss: 0.9973 - val_accuracy: 0.6200 - val_loss: 0.9986
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 174ms/step - accuracy: 0.6128 - loss: 0.9884 - val_accuracy: 0.5950 - val_loss: 0.9585
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 175ms/step - accuracy: 0.6142 - loss: 0.9715 - val_accuracy: 0.6150 - val_loss: 0.9203
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 186ms/step - accuracy: 0.5961 - loss: 0.9585 - val_accuracy: 0.6550 - val_loss: 0.9048
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.6442 - loss: 0.9424 - val_accuracy: 0.6550 - val_loss: 0.9357
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 199ms/step - accuracy: 0.6387 - loss: 0.9558 - val_accuracy: 0.6250 - val_loss: 0.9472
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.6458 - loss: 0.9347 - val_accuracy: 0.6750 - val_loss: 0.8893
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.6924 - loss: 0.8992 - val_accuracy: 0.6900 - val_loss: 0.8513
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.6503 - loss: 0.9405 - val_accuracy: 0.6900 - val_loss: 0.8845
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.6441 - loss: 0.9298 - val_accuracy: 0.6750 - val_loss: 0.8517
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.6657 - loss: 0.8656 - val_accuracy: 0.7350 - val_loss: 0.8119
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.6918 - loss: 0.8811 - val_accuracy: 0.7050 - val_loss: 0.8088
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.7092 - loss: 0.8289 - val_accuracy: 0.7200 - val_loss: 0.8299
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.6761 - loss: 0.8845 - val_accuracy: 0.7200 - val_loss: 0.7935
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.6946 - loss: 0.8221 - val_accuracy: 0.7200 - val_loss: 0.7684
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.6961 - loss: 0.8411 - val_accuracy: 0.7150 - val_loss: 0.7599
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 197ms/step - accuracy: 0.7272 - loss: 0.8020 - val_accuracy: 0.6950 - val_loss: 0.7627
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.7344 - loss: 0.7798 - val_accuracy: 0.7050 - val_loss: 0.7981
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.7042 - loss: 0.8285 - val_accuracy: 0.7050 - val_loss: 0.8368
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 221ms/step - accuracy: 0.6830 - loss: 0.8408 - val_accuracy: 0.7600 - val_loss: 0.7127
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.7445 - loss: 0.7509 - val_accuracy: 0.7700 - val_loss: 0.6780
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.7589 - loss: 0.7065 - val_accuracy: 0.7100 - val_loss: 0.7920
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.7300 - loss: 0.7914 - val_accuracy: 0.6500 - val_loss: 0.8837
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.6404 - loss: 0.9241 - val_accuracy: 0.6450 - val_loss: 0.9522
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.6190 - loss: 0.9437 - val_accuracy: 0.7350 - val_loss: 0.7809
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.7225 - loss: 0.7650 - val_accuracy: 0.7550 - val_loss: 0.7223
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.7212 - loss: 0.7463 - val_accuracy: 0.8150 - val_loss: 0.6542
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.7803 - loss: 0.6840 - val_accuracy: 0.7700 - val_loss: 0.6615
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.7604 - loss: 0.7462 - val_accuracy: 0.8000 - val_loss: 0.7061
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.7578 - loss: 0.7799 - val_accuracy: 0.8050 - val_loss: 0.6445
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.7688 - loss: 0.7061 - val_accuracy: 0.8200 - val_loss: 0.6227
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 219ms/step - accuracy: 0.8101 - loss: 0.6522 - val_accuracy: 0.8200 - val_loss: 0.5848
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.8066 - loss: 0.6233 - val_accuracy: 0.7800 - val_loss: 0.6456
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.7612 - loss: 0.7198 - val_accuracy: 0.8200 - val_loss: 0.5749
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.7933 - loss: 0.6175 - val_accuracy: 0.8300 - val_loss: 0.5576
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.7899 - loss: 0.6572 - val_accuracy: 0.8050 - val_loss: 0.5645
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.8067 - loss: 0.6258 - val_accuracy: 0.8150 - val_loss: 0.5520
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 218ms/step - accuracy: 0.7955 - loss: 0.6441 - val_accuracy: 0.8300 - val_loss: 0.5399
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 0.8143 - loss: 0.5964 - val_accuracy: 0.8200 - val_loss: 0.5435
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.7798 - loss: 0.6712 - val_accuracy: 0.8300 - val_loss: 0.5449
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 214ms/step - accuracy: 0.8052 - loss: 0.6087 - val_accuracy: 0.8300 - val_loss: 0.5210
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8110 - loss: 0.5658 - val_accuracy: 0.8350 - val_loss: 0.5241
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8144 - loss: 0.5751 - val_accuracy: 0.8400 - val_loss: 0.5276
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8317 - loss: 0.5481 - val_accuracy: 0.8350 - val_loss: 0.5016
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8144 - loss: 0.5570 - val_accuracy: 0.8250 - val_loss: 0.5052
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 215ms/step - accuracy: 0.8381 - loss: 0.5361 - val_accuracy: 0.8000 - val_loss: 0.5327
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.7688 - loss: 0.6677 - val_accuracy: 0.8250 - val_loss: 0.5174
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.7638 - loss: 0.6464 - val_accuracy: 0.8000 - val_loss: 0.5185
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.8099 - loss: 0.6063 - val_accuracy: 0.8450 - val_loss: 0.4917
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.8267 - loss: 0.5363 - val_accuracy: 0.8000 - val_loss: 0.5127
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 195ms/step - accuracy: 0.8234 - loss: 0.5351 - val_accuracy: 0.8000 - val_loss: 0.5196
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 210ms/step - accuracy: 0.7942 - loss: 0.5731 - val_accuracy: 0.8250 - val_loss: 0.4930
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 214ms/step - accuracy: 0.8045 - loss: 0.5571 - val_accuracy: 0.8200 - val_loss: 0.4840
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 216ms/step - accuracy: 0.8247 - loss: 0.5096 - val_accuracy: 0.7650 - val_loss: 0.6098
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.8048 - loss: 0.5611 - val_accuracy: 0.8250 - val_loss: 0.5085
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.8048 - loss: 0.5718 - val_accuracy: 0.8350 - val_loss: 0.4768
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.8123 - loss: 0.5386 - val_accuracy: 0.8400 - val_loss: 0.4684
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.8236 - loss: 0.5206 - val_accuracy: 0.8300 - val_loss: 0.4838
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.8029 - loss: 0.5364 - val_accuracy: 0.8250 - val_loss: 0.5284
# Epoch 96/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8045 - loss: 0.5381 - val_accuracy: 0.8100 - val_loss: 0.5010
# Epoch 97/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 201ms/step - accuracy: 0.8264 - loss: 0.5128 - val_accuracy: 0.8050 - val_loss: 0.5016
# Epoch 98/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 217ms/step - accuracy: 0.8168 - loss: 0.5219 - val_accuracy: 0.8250 - val_loss: 0.4715
# Epoch 99/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 0.8254 - loss: 0.5150 - val_accuracy: 0.8250 - val_loss: 0.5051
# Epoch 100/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.8035 - loss: 0.5449 - val_accuracy: 0.8200 - val_loss: 0.4889
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step
# Training Accuracy (LSTM): 0.83625
# Testing Accuracy (LSTM): 0.82

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Calculate confusion matrix for training data
conf_matrix_train = confusion_matrix(Y_train_encoded, y_train_pred_lstm)

# Calculate confusion matrix for testing data
conf_matrix_test = confusion_matrix(Y_test_encoded, y_test_pred_lstm)

# Function to plot confusion matrix
def plot_confusion_matrix(conf_matrix, title):
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_to_folder))
    plt.xticks(tick_marks, label_to_folder.keys(), rotation=45)
    plt.yticks(tick_marks, label_to_folder.keys())
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    for i in range(len(conf_matrix)):
        for j in range(len(conf_matrix)):
            plt.text(j, i, format(conf_matrix[i, j]), horizontalalignment="center", color="white" if conf_matrix[i, j] > np.max(conf_matrix)/2 else "black")
    plt.tight_layout()
    plt.show()

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train, title="Confusion Matrix - LSTM Training Data")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test, title="Confusion Matrix - LSTM  Testing Data")

# %%
X_train.shape
# Out:
# (800, 360)

# %%
X_test.shape
# Out:
# (200, 360)

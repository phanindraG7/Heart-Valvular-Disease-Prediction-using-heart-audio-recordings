# %%
import os
import time
import numpy as np
import pandas as pd
import scipy.io as sio
from scipy.fftpack import fft
from IPython.display import display

import pywt
import scipy.stats

import datetime as dt
from collections import defaultdict, Counter

from sklearn.ensemble import GradientBoostingClassifier

# %%
# Define statistical feature calculation function
def calculate_statistics(list_values):
    n5 = np.nanpercentile(list_values, 5)
    n25 = np.nanpercentile(list_values, 25)
    n75 = np.nanpercentile(list_values, 75)
    n95 = np.nanpercentile(list_values, 95)
    median = np.nanpercentile(list_values, 50)
    mean = np.nanmean(list_values)
    std = np.nanstd(list_values)
    var = np.nanvar(list_values)
    rms = np.nanmean(np.sqrt(list_values**2))
    return [n5, n25, n75, n95, median, mean, std, var, rms]

def calculate_entropy(list_values):
    counter_values = Counter(list_values).most_common()
    probabilities = [elem[1]/len(list_values) for elem in counter_values]
    entropy=scipy.stats.entropy(probabilities)
    return entropy

def calculate_crossings(list_values):
    zero_crossing_indices = np.nonzero(np.diff(np.array(list_values) > 0))[0]
    no_zero_crossings = len(zero_crossing_indices)
    mean_crossing_indices = np.nonzero(np.diff(np.array(list_values) > np.nanmean(list_values)))[0]
    no_mean_crossings = len(mean_crossing_indices)
    return [no_zero_crossings, no_mean_crossings]

def get_features(list_values):
    entropy = calculate_entropy(list_values)
    crossings = calculate_crossings(list_values)
    statistics = calculate_statistics(list_values)
    return [entropy] + crossings + statistics

def get_train_test(df, y_col, x_cols, ratio):
    """ 
    This method transforms a dataframe into a train and test set, for this you need to specify:
    1. the ratio train : test (usually 0.7)
    2. the column with the Y_values
    """
    mask = np.random.rand(len(df)) < ratio
    df_train = df[mask]
    df_test = df[~mask]
       
    Y_train = df_train[y_col].values
    Y_test = df_test[y_col].values
    X_train = df_train[x_cols].values
    X_test = df_test[x_cols].values
    return df_train, df_test, X_train, Y_train, X_test, Y_test

# %%
import os
import pandas as pd
import numpy as np
import librosa
import pywt
from tqdm import tqdm

# Define function for feature extraction using MFCC and mean
def features_extractor(file_path):
    # Load audio file
    audio_data, sample_rate = librosa.load(file_path, sr=None)
    
    # Extract MFCC features
    mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=13)
    
    # Take the mean of MFCC coefficients along the time axis
    mfcc_mean = np.mean(mfccs, axis=1)
    
    return mfcc_mean.tolist()  # Convert to list for easier appending to features list
# Define a function for Continuous Wavelet Transform (CWT) feature extraction
def cwt_features_extractor(features):
    scales = np.arange(1, 31)  # Define the range of scales for CWT
    coefficients, _ = pywt.cwt(features, scales, 'morl')  # 'morl' is the Morlet wavelet
    features1 = []
    for coeff in coefficients:
        # Calculate statistical features for each coefficient
        features1 += get_features(coeff)
    return features1


# Define function for DWT feature extraction
def dwt_features_extractor(features):
    # Perform DWT
    coeffs = pywt.wavedec(features, 'db1', level=4)  # 'db1' is the Daubechies wavelet family
    features = []
    for coeff in coeffs:
        # Calculate statistical features for each coefficient
        features += get_features(coeff)  # Assuming you have a function get_features() that returns features
    
    # # Flatten the coefficients to obtain a 1D feature vector
    # flattened_coeffs = np.concatenate(features)
    
    return features

# Define path and mappings
audio_dataset_path = r"D:\SDP\Dataset"
metadata = pd.read_csv('HVD_Data.csv')

label_to_folder = {
    "AS": "AS_New",
    "MR": "MR_New",
    "MS": "MS_New",
    "MVP": "MVP_New",
    "N": "N_New"
}

# Iterate through metadata and extract features
extracted_features = []
list_labels = []  # List to store labels
for index_num, row in tqdm(metadata.iterrows()):
    file_label = row["Label"]  # Change "Label" to the correct column name
    folder_name = label_to_folder.get(file_label)
    if folder_name:
        file_name = os.path.join(audio_dataset_path, folder_name, row["Name"])
        mfcc_features = features_extractor(file_name)
        cwt_features = cwt_features_extractor(mfcc_features)  # Extract CWT features from MFCC
        dwt_features = dwt_features_extractor(cwt_features)  # Extract DWT features from CWT
        extracted_features.append(dwt_features)
        list_labels.append(file_label)


# Create DataFrame from extracted features and labels
df = pd.DataFrame(extracted_features)
df['label'] = list_labels

# Split data into train and test sets (You can use train_test_split from sklearn)
from sklearn.model_selection import train_test_split
df_train, df_test = train_test_split(df, test_size=0.2, stratify=df['label'],random_state=42)  # Adjust test_size as needed

# Separate features and labels for train and test sets
X_train, Y_train = df_train.drop('label', axis=1), df_train['label']
X_test, Y_test = df_test.drop('label', axis=1), df_test['label']
# Out:
# 1000it [02:41,  6.18it/s]

# %%
X_train.shape
# Out:
# (800, 60)

# %%
Y_train.shape
# Out:
# (800,)

# %% [markdown]
# ### Gradient Decent Classifier

# %%
cls = GradientBoostingClassifier(n_estimators=10000)
cls.fit(X_train, Y_train)
train_score = cls.score(X_train, Y_train)
test_score = cls.score(X_test, Y_test)
print("The Train Score is {}".format(train_score))
print("The Test Score is {}".format(test_score))
# Out:
# The Train Score is 1.0
# The Test Score is 0.94

# %%
# Function to plot confusion matrix
def plot_confusion_matrix(conf_matrix, title):
    plt.figure(figsize=(8, 6))
    plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(label_to_folder))
    plt.xticks(tick_marks, label_to_folder.keys(), rotation=45)
    plt.yticks(tick_marks, label_to_folder.keys())
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    for i in range(len(conf_matrix)):
        for j in range(len(conf_matrix)):
            plt.text(j, i, format(conf_matrix[i, j]), horizontalalignment="center", color="white" if conf_matrix[i, j] > np.max(conf_matrix)/2 else "black")
    plt.tight_layout()
    plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Predictions
y_train_pred_gb = cls.predict(X_train)
y_test_pred_gb = cls.predict(X_test)

# Calculate confusion matrix for training data
conf_matrix_train_gb = confusion_matrix(Y_train, y_train_pred_gb)

# Calculate confusion matrix for testing data
conf_matrix_test_gb = confusion_matrix(Y_test, y_test_pred_gb)

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train_gb, title="Confusion Matrix - Training Data (Gradient Boosting)")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test_gb, title="Confusion Matrix - Testing Data (Gradient Boosting)")

# %% [markdown]
# ### KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# Create KNN model
knn_model = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (n_neighbors) as needed

# Train the model
knn_model.fit(X_train, Y_train_encoded)  # Use integer-encoded labels directly

# Predictions
y_train_pred_knn = knn_model.predict(X_train)
y_test_pred_knn = knn_model.predict(X_test)

# Calculate accuracy
train_accuracy_knn = accuracy_score(Y_train_encoded, y_train_pred_knn)
test_accuracy_knn = accuracy_score(Y_test_encoded, y_test_pred_knn)

print("Training Accuracy (KNN):", train_accuracy_knn)
print("Testing Accuracy (KNN):", test_accuracy_knn)
# Out:
# Training Accuracy (KNN): 0.8875
# Testing Accuracy (KNN): 0.795

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Calculate confusion matrix for training data
conf_matrix_train_knn = confusion_matrix(Y_train_encoded, y_train_pred_knn)

# Calculate confusion matrix for testing data
conf_matrix_test_knn = confusion_matrix(Y_test_encoded, y_test_pred_knn)

# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train_knn, title="Confusion Matrix - Training Data (KNN)")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test_knn, title="Confusion Matrix - Testing Data (KNN)")

# %% [markdown]
# ### LSTM

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from sklearn.metrics import accuracy_score

# Assuming you have already defined X_train, X_test, Y_train_encoded, and Y_test_encoded

# Reshape X_train and X_test
X_train_reshaped = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test_reshaped = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Define LSTM model
lstm_model = Sequential([
    LSTM(100, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])),
    Dense(5, activation='softmax')
])

# Compile the model
lstm_model.compile(optimizer='adam',
                   loss='sparse_categorical_crossentropy',
                   metrics=['accuracy'])

# Train the model
lstm_model.fit(X_train_reshaped, Y_train_encoded, epochs=100, validation_data=(X_test_reshaped, Y_test_encoded))

# Predictions
y_train_pred_lstm_probs = lstm_model.predict(X_train_reshaped)
y_train_pred_lstm = np.argmax(y_train_pred_lstm_probs, axis=1)

y_test_pred_lstm_probs = lstm_model.predict(X_test_reshaped)
y_test_pred_lstm = np.argmax(y_test_pred_lstm_probs, axis=1)

# Calculate accuracy
train_accuracy_lstm = accuracy_score(Y_train_encoded, y_train_pred_lstm)
test_accuracy_lstm = accuracy_score(Y_test_encoded, y_test_pred_lstm)

print("Training Accuracy (LSTM):", train_accuracy_lstm)
print("Testing Accuracy (LSTM):", test_accuracy_lstm)
# Out:
# C:\Users\G phanindra\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.2136 - loss: 1.6200 - val_accuracy: 0.2950 - val_loss: 1.5908
# Epoch 2/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.2950 - loss: 1.5851 - val_accuracy: 0.3850 - val_loss: 1.5589
# Epoch 3/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.2784 - loss: 1.5490 - val_accuracy: 0.2600 - val_loss: 1.5413
# Epoch 4/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.3064 - loss: 1.5282 - val_accuracy: 0.2950 - val_loss: 1.5116
# Epoch 5/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.3302 - loss: 1.4891 - val_accuracy: 0.3450 - val_loss: 1.4916
# Epoch 6/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.3298 - loss: 1.4774 - val_accuracy: 0.2950 - val_loss: 1.4609
# Epoch 7/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.3412 - loss: 1.4417 - val_accuracy: 0.2800 - val_loss: 1.4469
# Epoch 8/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.3686 - loss: 1.4187 - val_accuracy: 0.3450 - val_loss: 1.4286
# Epoch 9/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.3728 - loss: 1.3745 - val_accuracy: 0.4000 - val_loss: 1.3993
# Epoch 10/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.3809 - loss: 1.3723 - val_accuracy: 0.3600 - val_loss: 1.3901
# Epoch 11/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.3903 - loss: 1.3582 - val_accuracy: 0.3550 - val_loss: 1.3487
# Epoch 12/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.3946 - loss: 1.3137 - val_accuracy: 0.4200 - val_loss: 1.3163
# Epoch 13/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.4404 - loss: 1.2922 - val_accuracy: 0.4250 - val_loss: 1.2994
# Epoch 14/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.4214 - loss: 1.3137 - val_accuracy: 0.4650 - val_loss: 1.2815
# Epoch 15/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.4657 - loss: 1.2356 - val_accuracy: 0.4450 - val_loss: 1.2847
# Epoch 16/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.4517 - loss: 1.2631 - val_accuracy: 0.4950 - val_loss: 1.2364
# Epoch 17/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.5054 - loss: 1.1930 - val_accuracy: 0.5300 - val_loss: 1.2212
# Epoch 18/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.5602 - loss: 1.1895 - val_accuracy: 0.6300 - val_loss: 1.1580
# Epoch 19/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6255 - loss: 1.1339 - val_accuracy: 0.5800 - val_loss: 1.1743
# Epoch 20/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.6054 - loss: 1.1263 - val_accuracy: 0.6150 - val_loss: 1.1311
# Epoch 21/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.6120 - loss: 1.0848 - val_accuracy: 0.6000 - val_loss: 1.0855
# Epoch 22/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.6036 - loss: 1.0568 - val_accuracy: 0.6350 - val_loss: 1.0826
# Epoch 23/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 90ms/step - accuracy: 0.5971 - loss: 1.0409 - val_accuracy: 0.6250 - val_loss: 1.0636
# Epoch 24/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.6127 - loss: 1.0344 - val_accuracy: 0.5500 - val_loss: 1.0844
# Epoch 25/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.5959 - loss: 1.0095 - val_accuracy: 0.6850 - val_loss: 0.9925
# Epoch 26/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.6948 - loss: 0.9210 - val_accuracy: 0.6350 - val_loss: 0.9788
# Epoch 27/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step - accuracy: 0.6495 - loss: 0.9261 - val_accuracy: 0.6400 - val_loss: 0.9674
# Epoch 28/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.6254 - loss: 0.9594 - val_accuracy: 0.6450 - val_loss: 0.9190
# Epoch 29/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.6730 - loss: 0.9160 - val_accuracy: 0.6450 - val_loss: 0.9027
# Epoch 30/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6877 - loss: 0.8461 - val_accuracy: 0.6150 - val_loss: 1.0290
# Epoch 31/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.6552 - loss: 0.9245 - val_accuracy: 0.7550 - val_loss: 0.8790
# Epoch 32/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.7196 - loss: 0.8387 - val_accuracy: 0.6050 - val_loss: 0.8759
# Epoch 33/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.6853 - loss: 0.8615 - val_accuracy: 0.6800 - val_loss: 0.8086
# Epoch 34/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.7043 - loss: 0.8227 - val_accuracy: 0.7200 - val_loss: 0.8039
# Epoch 35/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7244 - loss: 0.7965 - val_accuracy: 0.7550 - val_loss: 0.7691
# Epoch 36/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.7025 - loss: 0.8118 - val_accuracy: 0.7750 - val_loss: 0.7909
# Epoch 37/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.7427 - loss: 0.7854 - val_accuracy: 0.8000 - val_loss: 0.7485
# Epoch 38/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.7437 - loss: 0.7416 - val_accuracy: 0.8000 - val_loss: 0.7137
# Epoch 39/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.7647 - loss: 0.7247 - val_accuracy: 0.7250 - val_loss: 0.7221
# Epoch 40/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.7825 - loss: 0.6469 - val_accuracy: 0.7950 - val_loss: 0.6709
# Epoch 41/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7819 - loss: 0.6440 - val_accuracy: 0.8150 - val_loss: 0.6525
# Epoch 42/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.7810 - loss: 0.6233 - val_accuracy: 0.8100 - val_loss: 0.6517
# Epoch 43/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.7769 - loss: 0.6313 - val_accuracy: 0.8100 - val_loss: 0.6209
# Epoch 44/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.7720 - loss: 0.6411 - val_accuracy: 0.8200 - val_loss: 0.6354
# Epoch 45/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - accuracy: 0.8059 - loss: 0.5748 - val_accuracy: 0.8200 - val_loss: 0.6147
# Epoch 46/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8065 - loss: 0.5524 - val_accuracy: 0.8400 - val_loss: 0.5588
# Epoch 47/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - accuracy: 0.8039 - loss: 0.6049 - val_accuracy: 0.8200 - val_loss: 0.6049
# Epoch 48/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.8056 - loss: 0.5525 - val_accuracy: 0.8400 - val_loss: 0.5698
# Epoch 49/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - accuracy: 0.8182 - loss: 0.5405 - val_accuracy: 0.8000 - val_loss: 0.6204
# Epoch 50/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - accuracy: 0.7976 - loss: 0.5941 - val_accuracy: 0.8300 - val_loss: 0.5438
# Epoch 51/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - accuracy: 0.8176 - loss: 0.5350 - val_accuracy: 0.8350 - val_loss: 0.5610
# Epoch 52/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.8018 - loss: 0.5389 - val_accuracy: 0.8400 - val_loss: 0.5267
# Epoch 53/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8121 - loss: 0.5334 - val_accuracy: 0.8050 - val_loss: 0.6147
# Epoch 54/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - accuracy: 0.8081 - loss: 0.5003 - val_accuracy: 0.8250 - val_loss: 0.5211
# Epoch 55/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8302 - loss: 0.4779 - val_accuracy: 0.8350 - val_loss: 0.5208
# Epoch 56/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8349 - loss: 0.4882 - val_accuracy: 0.8300 - val_loss: 0.5615
# Epoch 57/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8351 - loss: 0.4768 - val_accuracy: 0.8350 - val_loss: 0.5296
# Epoch 58/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.7802 - loss: 0.5340 - val_accuracy: 0.8200 - val_loss: 0.5745
# Epoch 59/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8257 - loss: 0.4892 - val_accuracy: 0.8400 - val_loss: 0.5337
# Epoch 60/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8628 - loss: 0.4371 - val_accuracy: 0.8600 - val_loss: 0.4894
# Epoch 61/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8235 - loss: 0.4952 - val_accuracy: 0.8150 - val_loss: 0.6116
# Epoch 62/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8097 - loss: 0.5503 - val_accuracy: 0.8550 - val_loss: 0.5075
# Epoch 63/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8414 - loss: 0.4649 - val_accuracy: 0.8350 - val_loss: 0.5484
# Epoch 64/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8261 - loss: 0.4499 - val_accuracy: 0.8650 - val_loss: 0.4970
# Epoch 65/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8687 - loss: 0.4447 - val_accuracy: 0.8600 - val_loss: 0.4677
# Epoch 66/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8703 - loss: 0.3893 - val_accuracy: 0.8800 - val_loss: 0.4608
# Epoch 67/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8597 - loss: 0.4356 - val_accuracy: 0.8600 - val_loss: 0.4675
# Epoch 68/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8689 - loss: 0.4085 - val_accuracy: 0.8300 - val_loss: 0.4985
# Epoch 69/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.8515 - loss: 0.4167 - val_accuracy: 0.8700 - val_loss: 0.4588
# Epoch 70/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8750 - loss: 0.4073 - val_accuracy: 0.8800 - val_loss: 0.4279
# Epoch 71/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8873 - loss: 0.3723 - val_accuracy: 0.8700 - val_loss: 0.4774
# Epoch 72/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8424 - loss: 0.4437 - val_accuracy: 0.8150 - val_loss: 0.5693
# Epoch 73/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.8367 - loss: 0.4492 - val_accuracy: 0.8800 - val_loss: 0.4415
# Epoch 74/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8470 - loss: 0.4418 - val_accuracy: 0.8650 - val_loss: 0.4789
# Epoch 75/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.8396 - loss: 0.4439 - val_accuracy: 0.8500 - val_loss: 0.4441
# Epoch 76/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.8932 - loss: 0.3700 - val_accuracy: 0.8800 - val_loss: 0.4353
# Epoch 77/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8593 - loss: 0.3832 - val_accuracy: 0.8750 - val_loss: 0.4462
# Epoch 78/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8892 - loss: 0.3533 - val_accuracy: 0.8400 - val_loss: 0.5110
# Epoch 79/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.8660 - loss: 0.4592 - val_accuracy: 0.8350 - val_loss: 0.5151
# Epoch 80/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8712 - loss: 0.4129 - val_accuracy: 0.8800 - val_loss: 0.4076
# Epoch 81/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8904 - loss: 0.3397 - val_accuracy: 0.8900 - val_loss: 0.3918
# Epoch 82/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 88ms/step - accuracy: 0.8835 - loss: 0.3627 - val_accuracy: 0.8850 - val_loss: 0.3928
# Epoch 83/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8592 - loss: 0.3835 - val_accuracy: 0.8750 - val_loss: 0.4539
# Epoch 84/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.8867 - loss: 0.3462 - val_accuracy: 0.8600 - val_loss: 0.4531
# Epoch 85/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.8802 - loss: 0.3817 - val_accuracy: 0.8750 - val_loss: 0.4446
# Epoch 86/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - accuracy: 0.8824 - loss: 0.3877 - val_accuracy: 0.8850 - val_loss: 0.4438
# Epoch 87/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - accuracy: 0.8866 - loss: 0.3451 - val_accuracy: 0.8650 - val_loss: 0.4212
# Epoch 88/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - accuracy: 0.8928 - loss: 0.3225 - val_accuracy: 0.8850 - val_loss: 0.3898
# Epoch 89/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9066 - loss: 0.3080 - val_accuracy: 0.8900 - val_loss: 0.3637
# Epoch 90/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 147ms/step - accuracy: 0.9064 - loss: 0.3093 - val_accuracy: 0.8950 - val_loss: 0.3673
# Epoch 91/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8954 - loss: 0.3070 - val_accuracy: 0.8950 - val_loss: 0.3474
# Epoch 92/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.8928 - loss: 0.3388 - val_accuracy: 0.8900 - val_loss: 0.3836
# Epoch 93/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.9039 - loss: 0.2931 - val_accuracy: 0.8900 - val_loss: 0.3565
# Epoch 94/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 93ms/step - accuracy: 0.9077 - loss: 0.3001 - val_accuracy: 0.9050 - val_loss: 0.3676
# Epoch 95/100
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 102ms/step - accuracy: 0.9244 - loss: 0.2728 - val_accuracy: 0.9000 - val_loss: 0.3756
# Epoch 96/100
# 17/25 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.9234 - loss: 0.2613

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt

# Calculate confusion matrix for training data
conf_matrix_train = confusion_matrix(Y_train_encoded, y_train_pred_lstm)

# Calculate confusion matrix for testing data
conf_matrix_test = confusion_matrix(Y_test_encoded, y_test_pred_lstm)



# Plot confusion matrix for training data
plot_confusion_matrix(conf_matrix_train, title="Confusion Matrix - LSTM Training Data")

# Plot confusion matrix for testing data
plot_confusion_matrix(conf_matrix_test, title="Confusion Matrix - LSTM  Testing Data")
